# %%
### Created by Tazein Shah on 1/17/24
## this is just to observe how a stem plot looks like in Julia

# %%
#using Pkg
#Pkg.add("Plots")
using Plots

x = 1:10
y = rand(10)

plot(x, y, seriestype=:stem, marker=:circle, line=:stem, legend=false)

# %%
# testing this stem plot with a matrix where the row is one single value

# Example matrix of Bool values
bool_matrix = [
    true  false true  false false true
    false true  false true  true  false
    true  true  true  false false false
    false false true  true  true  true
    true  false false false true  false
    false true  false true  false true
]

# Get the size of the matrix
num_rows, num_cols = size(bool_matrix)

# Initialize an empty list to store rows
rows_list = []

# Loop through each row and append it to the list
for i in 1:num_rows
    push!(rows_list, bool_matrix[i, :])
end

rows_list
# Out:
# 6-element Vector{Any}:
#  Bool[1, 0, 1, 0, 0, 1]
#  Bool[0, 1, 0, 1, 1, 0]
#  Bool[1, 1, 1, 0, 0, 0]
#  Bool[0, 0, 1, 1, 1, 1]
#  Bool[1, 0, 0, 0, 1, 0]
#  Bool[0, 1, 0, 1, 0, 1]

# %%
new_matrix
# Out:
# 4×1 Matrix{Int64}:
#  21
#  57
#  21
#  26
